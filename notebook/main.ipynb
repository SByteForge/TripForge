# %%
import pandas as pd
import pyarrow.parquet as pq
import os

# %%
pd.read_parquet("./Data/fhv_tripdata_2024-01.parquet")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.read_parquet("./Data/fhv_tripdata_2024-01.parquet")
#
# File ~/DevForge/FakeTaxi/vFakeTaxi/lib/python3.11/site-packages/pandas/io/parquet.py:651, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     498 @doc(storage_options=_shared_docs["storage_options"])
#     499 def read_parquet(
#     500     path: FilePath | ReadBuffer[bytes],
#    (...)
#     508     **kwargs,
#     509 ) -> DataFrame:
#     510     """
#     511     Load a parquet object from the file path, returning a DataFrame.
#     512
#    (...)
#     648     1    4    9
#     649     """
# --> 651     impl = get_engine(engine)
#     653     if use_nullable_dtypes is not lib.no_default:
#     654         msg = (
# ...

# %%
pd.read_parquet("./Data/fhv_tripdata_2024-01.parquet")
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00053 2024-01-01 00:15:00 2024-01-01 02:13:00
# 1                     B00111 2024-01-01 00:30:00 2024-01-01 02:37:00
# 2                     B00112 2024-01-01 00:27:24 2024-01-01 01:12:05
# 3                     B00112 2024-01-01 00:10:09 2024-01-01 00:25:39
# 4                     B00112 2024-01-01 00:57:07 2024-01-01 01:05:04
# ...                      ...                 ...                 ...
# 1290111               B03492 2024-01-31 23:51:21 2024-01-31 23:57:09
# 1290112               B03492 2024-01-31 23:05:06 2024-01-31 23:20:13
# 1290113               B03492 2024-01-31 23:49:07 2024-02-01 00:16:25
# 1290114               B03505 2024-01-31 23:04:46 2024-01-31 23:18:22
# 1290115               B03529 2024-01-31 23:45:30 2024-01-31 23:59:25
#
#          PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 0                 NaN           NaN      NaN                 B00014
# ...
